# %% [markdown]
# <a href="https://colab.research.google.com/github/ipez02/csci164/blob/main/cs166training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet "gymnasium[atari,accept-rom-license]" stable-baselines3[extra] autorom[accept-rom-license]
# !AutoROM --accept-license
# Out:
# WARNING: gymnasium 1.2.0 does not provide the extra 'accept-rom-license'
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.

# %%
# !pip install ale-py
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: numpy>1.20 in /usr/local/lib/python3.12/dist-packages (from ale-py) (2.0.2)

# %%
import gymnasium as gym


print(gym.envs.registry.keys())
# Out:
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v3', 'LunarLanderContinuous-v3', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v3', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v1', 'CliffWalkingSlippery-v1', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Reacher-v5', 'Pusher-v2', 'Pusher-v4', 'Pusher-v5', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedPendulum-v5', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'InvertedDoublePendulum-v5', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'HalfCheetah-v5', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Hopper-v5', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Swimmer-v5', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Walker2d-v5', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Ant-v5', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'Humanoid-v5', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'HumanoidStandup-v5', 'GymV21Environment-v0', 'GymV26Environment-v0'])

# %%
import ale_py
import gymnasium as gym

# %%
# =====================================================
# DQN on Atari Space Invaders (based on Pong starter)
# =====================================================

# !pip install --quiet "gymnasium[atari,accept-rom-license]" stable-baselines3[extra] ale-py
# !AutoROM --accept-license

import os
# Set the ATARI_ROM_DIRS environment variable
# IMPORTANT: Update this path if your ROMs are in a different location
# os.environ["ATARI_ROM_DIRS"] = "/usr/local/lib/python3.10/dist-packages/ale_py/roms/"
# The above line might be needed depending on your setup if AutoROM doesn't place
# ROMs in a discoverable location.

import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from gymnasium.wrappers import RecordVideo # No longer explicitly importing FrameStack/FrameStackObservation


# Corrected import path for make_atari and wrap_deepmind
from stable_baselines3.common.env_util import make_atari_env
# from stable_baselines3.common.atari_wrappers import AtariWrapper # No longer directly using AtariWrapper args this way

# ------------------------------------------
# 1. Environment Setup
# ------------------------------------------

def make_env():
    # Using make_atari_env with "NoFrameskip" version, which often handles preprocessing including frame stacking
    base_env = make_atari_env("SpaceInvadersNoFrameskip-v4", n_envs=1, seed=0)
    # Access the single environment within the VecEnv returned by make_atari_env
    single_env = base_env.envs[0]
    # Wrap the single environment with Monitor
    monitored_env = Monitor(single_env)
    # Return the monitored single environment
    return monitored_env

env = DummyVecEnv([lambda: make_env()]) # DummyVecEnv expects a function that returns the env

# ------------------------------------------
# 2. DQN Model
# ------------------------------------------

model = DQN(
    "CnnPolicy",
    env,
    buffer_size=100000,
    learning_rate=1e-4,
    batch_size=32,
    train_freq=4,
    target_update_interval=1000,
    exploration_fraction=0.1,
    exploration_final_eps=0.01,
    verbose=1,
)

# ------------------------------------------
# 3. Training Runs (Early + Later)
# ------------------------------------------

# Early run (mostly random)
print("Starting early training run...")
model.learn(total_timesteps=5000)
model.save("dqn_spaceinvaders_early")
print("Early training run finished.")

# Continue training for longer run
print("Starting later training run...")
model.learn(total_timesteps=100000)
model.save("dqn_spaceinvaders_later")
print("Later training run finished.")

# ------------------------------------------
# 4. Video Recording
# ------------------------------------------

os.makedirs("videos", exist_ok=True)

def record_video(model_path, save_name, max_steps=2000):
    print(f"Recording video for {save_name}...")
    # Use make_atari_env with "NoFrameskip" version for evaluation as well
    eval_env = make_atari_env("SpaceInvadersNoFrameskip-v4", n_envs=1, seed=0)
    # RecordVideo expects a single env, so access the unwrapped env from the VecEnv
    record_env = RecordVideo(
        eval_env.envs[0],
        video_folder="videos",
        name_prefix=save_name
    )

    model = DQN.load(model_path)

    obs, _ = record_env.reset() # Use record_env here
    done = False
    steps = 0
    while not done and steps < max_steps:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, _ = record_env.step(action) # Use record_env here
        done = terminated or truncated
        steps += 1

    record_env.close() # Close record_env
    print(f"Video recording for {save_name} finished.")


# Record both early and later runs
record_video("dqn_spaceinvaders_early", "spaceinvaders_early")
record_video("dqn_spaceinvaders_later", "spaceinvaders_later")

print("✅ Videos saved to /videos/")
# Out:
# WARNING: gymnasium 1.2.0 does not provide the extra 'accept-rom-license'
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Starting early training run...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 49       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 658      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000968 |
# |    n_updates        | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 4.88     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 44       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2342     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00129  |
# |    n_updates        | 560      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 4.92     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 44       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 3308     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000977 |
# |    n_updates        | 801      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 249      |
# |    ep_rew_mean      | 5.06     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 43       |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 3988     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000626 |
# |    n_updates        | 971      |
# ----------------------------------
# Early training run finished.
# Starting later training run...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 57       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 498      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00143  |
# |    n_updates        | 1324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 49       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1010     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00112  |
# |    n_updates        | 1452     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | 3        |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 46       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1898     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00036  |
# |    n_updates        | 1674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 3        |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 45       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2391     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000872 |
# |    n_updates        | 1797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | 2.8      |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 44       |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 3167     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 1991     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 3.42     |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 43       |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 4062     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000867 |
# |    n_updates        | 2215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | 3.21     |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 43       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 4622     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000502 |
# |    n_updates        | 2355     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 3.81     |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 42       |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 5905     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 2676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 3.67     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 42       |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 6512     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 2827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 3.45     |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 42       |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 6933     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 2933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 3.39     |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 42       |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 7305     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 3026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | 3.27     |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 42       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 7833     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0349   |
# |    n_updates        | 3158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 41       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 8781     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 3395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 3.64     |
# |    exploration_rate | 0.0202   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 41       |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 9897     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 3674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 3.65     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 41       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 10743    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00115  |
# |    n_updates        | 3885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 3.77     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 41       |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 11698    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00117  |
# |    n_updates        | 4124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 3.96     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 41       |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 12851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000786 |
# |    n_updates        | 4412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 3.99     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 41       |
# |    time_elapsed     | 329      |
# |    total_timesteps  | 13539    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 4584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.53     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 41       |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 15168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 4991     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 4.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 40       |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 15512    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 5077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 4.29     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 40       |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 16177    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 5244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 4.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 40       |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 17290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 5522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 40       |
# |    time_elapsed     | 446      |
# |    total_timesteps  | 18202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 5750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 4.36     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 40       |
# |    time_elapsed     | 462      |
# |    total_timesteps  | 18826    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00329  |
# |    n_updates        | 5906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 4.4      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 40       |
# |    time_elapsed     | 484      |
# |    total_timesteps  | 19705    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00142  |
# |    n_updates        | 6126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 4.52     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 40       |
# |    time_elapsed     | 503      |
# |    total_timesteps  | 20434    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 6308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 4.54     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 40       |
# |    time_elapsed     | 524      |
# |    total_timesteps  | 21244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00249  |
# |    n_updates        | 6510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 4.48     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 40       |
# |    time_elapsed     | 535      |
# |    total_timesteps  | 21683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 6620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 4.56     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 40       |
# |    time_elapsed     | 557      |
# |    total_timesteps  | 22567    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00255  |
# |    n_updates        | 6841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 4.61     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 40       |
# |    time_elapsed     | 573      |
# |    total_timesteps  | 23213    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 7003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 4.73     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 40       |
# |    time_elapsed     | 598      |
# |    total_timesteps  | 24181    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 7245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 4.78     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 40       |
# |    time_elapsed     | 615      |
# |    total_timesteps  | 24871    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0283   |
# |    n_updates        | 7417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 4.65     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 40       |
# |    time_elapsed     | 640      |
# |    total_timesteps  | 25851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000928 |
# |    n_updates        | 7662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 4.77     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 40       |
# |    time_elapsed     | 660      |
# |    total_timesteps  | 26638    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.031    |
# |    n_updates        | 7859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | 4.87     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 40       |
# |    time_elapsed     | 689      |
# |    total_timesteps  | 27835    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0326   |
# |    n_updates        | 8158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 4.98     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 40       |
# |    time_elapsed     | 714      |
# |    total_timesteps  | 28797    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00464  |
# |    n_updates        | 8399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 5.17     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 40       |
# |    time_elapsed     | 738      |
# |    total_timesteps  | 29748    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00103  |
# |    n_updates        | 8636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 5.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 40       |
# |    time_elapsed     | 755      |
# |    total_timesteps  | 30416    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00247  |
# |    n_updates        | 8803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 5.1      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 40       |
# |    time_elapsed     | 771      |
# |    total_timesteps  | 31049    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000932 |
# |    n_updates        | 8962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 40       |
# |    time_elapsed     | 791      |
# |    total_timesteps  | 31832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00874  |
# |    n_updates        | 9157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 5.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 40       |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 33131    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 9482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 5.21     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 40       |
# |    time_elapsed     | 854      |
# |    total_timesteps  | 34291    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00305  |
# |    n_updates        | 9772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 5.2      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 40       |
# |    time_elapsed     | 875      |
# |    total_timesteps  | 35168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 9991     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 4.75     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 40       |
# |    time_elapsed     | 900      |
# |    total_timesteps  | 36139    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 10234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 4.89     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 40       |
# |    time_elapsed     | 932      |
# |    total_timesteps  | 37381    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 10545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 5.09     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 40       |
# |    time_elapsed     | 964      |
# |    total_timesteps  | 38669    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 10867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 4.98     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 40       |
# |    time_elapsed     | 988      |
# |    total_timesteps  | 39600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 11099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 4.88     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 40       |
# |    time_elapsed     | 1002     |
# |    total_timesteps  | 40163    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 11240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 4.94     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 40       |
# |    time_elapsed     | 1014     |
# |    total_timesteps  | 40641    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00427  |
# |    n_updates        | 11360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 4.87     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 40       |
# |    time_elapsed     | 1033     |
# |    total_timesteps  | 41353    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 11538    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 5.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 39       |
# |    time_elapsed     | 1069     |
# |    total_timesteps  | 42782    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 11895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 5.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 40       |
# |    time_elapsed     | 1087     |
# |    total_timesteps  | 43515    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00965  |
# |    n_updates        | 12078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 5.11     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 39       |
# |    time_elapsed     | 1098     |
# |    total_timesteps  | 43947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00353  |
# |    n_updates        | 12186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 5.09     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 39       |
# |    time_elapsed     | 1121     |
# |    total_timesteps  | 44816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 12403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 5.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 39       |
# |    time_elapsed     | 1143     |
# |    total_timesteps  | 45709    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00153  |
# |    n_updates        | 12627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 5.09     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 39       |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 46838    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 12909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 5.05     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 39       |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 47421    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 13055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 39       |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 48373    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 13293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 4.96     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 39       |
# |    time_elapsed     | 1229     |
# |    total_timesteps  | 49115    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00615  |
# |    n_updates        | 13478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 4.98     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 39       |
# |    time_elapsed     | 1254     |
# |    total_timesteps  | 50117    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 13729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 5.01     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 39       |
# |    time_elapsed     | 1278     |
# |    total_timesteps  | 51065    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0586   |
# |    n_updates        | 13966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 4.91     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 39       |
# |    time_elapsed     | 1302     |
# |    total_timesteps  | 51989    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 14197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 4.93     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 39       |
# |    time_elapsed     | 1329     |
# |    total_timesteps  | 53075    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 14468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 5.02     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 39       |
# |    time_elapsed     | 1361     |
# |    total_timesteps  | 54304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00618  |
# |    n_updates        | 14775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 235      |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 39       |
# |    time_elapsed     | 1386     |
# |    total_timesteps  | 55284    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00506  |
# |    n_updates        | 15020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 5.08     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 39       |
# |    time_elapsed     | 1409     |
# |    total_timesteps  | 56184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 15245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 4.9      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 39       |
# |    time_elapsed     | 1428     |
# |    total_timesteps  | 56907    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00224  |
# |    n_updates        | 15426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 4.96     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 39       |
# |    time_elapsed     | 1445     |
# |    total_timesteps  | 57587    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00622  |
# |    n_updates        | 15596    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 5.09     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 39       |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 58393    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 15798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 5.16     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 39       |
# |    time_elapsed     | 1494     |
# |    total_timesteps  | 59489    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00252  |
# |    n_updates        | 16072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 5.1      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 39       |
# |    time_elapsed     | 1518     |
# |    total_timesteps  | 60424    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00905  |
# |    n_updates        | 16305    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 5.05     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 39       |
# |    time_elapsed     | 1532     |
# |    total_timesteps  | 61007    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.004    |
# |    n_updates        | 16451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 5.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 39       |
# |    time_elapsed     | 1581     |
# |    total_timesteps  | 62920    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 16929    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 5.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 39       |
# |    time_elapsed     | 1592     |
# |    total_timesteps  | 63362    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00223  |
# |    n_updates        | 17040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 5.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 39       |
# |    time_elapsed     | 1613     |
# |    total_timesteps  | 64154    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 17238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 5.1      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 39       |
# |    time_elapsed     | 1631     |
# |    total_timesteps  | 64896    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 17423    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 5.27     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 39       |
# |    time_elapsed     | 1661     |
# |    total_timesteps  | 66066    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00376  |
# |    n_updates        | 17716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 5.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 39       |
# |    time_elapsed     | 1683     |
# |    total_timesteps  | 66932    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00456  |
# |    n_updates        | 17932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 5.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 39       |
# |    time_elapsed     | 1707     |
# |    total_timesteps  | 67881    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.01     |
# |    n_updates        | 18170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 5.33     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 39       |
# |    time_elapsed     | 1720     |
# |    total_timesteps  | 68389    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00358  |
# |    n_updates        | 18297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 5.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 39       |
# |    time_elapsed     | 1736     |
# |    total_timesteps  | 69024    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 18455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 5.33     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 39       |
# |    time_elapsed     | 1758     |
# |    total_timesteps  | 69906    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 18676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 5.3      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 39       |
# |    time_elapsed     | 1774     |
# |    total_timesteps  | 70534    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 18833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 5.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 39       |
# |    time_elapsed     | 1791     |
# |    total_timesteps  | 71180    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 18994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 5.21     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 39       |
# |    time_elapsed     | 1808     |
# |    total_timesteps  | 71847    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 19161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 5.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 39       |
# |    time_elapsed     | 1831     |
# |    total_timesteps  | 72778    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 19394    |
# ----------------------------------
# ----------------------------------
# ...
# |    fps              | 39       |
# |    time_elapsed     | 1953     |
# |    total_timesteps  | 77508    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00321  |
# |    n_updates        | 20576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 5.3      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 39       |
# |    time_elapsed     | 1971     |
# |    total_timesteps  | 78236    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00475  |
# |    n_updates        | 20758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 5.3      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 39       |
# |    time_elapsed     | 1996     |
# |    total_timesteps  | 79191    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 20997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 5.16     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 39       |
# |    time_elapsed     | 2014     |
# |    total_timesteps  | 79895    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0657   |
# |    n_updates        | 21173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 5.14     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 39       |
# |    time_elapsed     | 2035     |
# |    total_timesteps  | 80718    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00365  |
# |    n_updates        | 21379    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 39       |
# |    time_elapsed     | 2052     |
# |    total_timesteps  | 81377    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 21544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 5.04     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 39       |
# |    time_elapsed     | 2071     |
# |    total_timesteps  | 82126    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 21731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 4.74     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 39       |
# |    time_elapsed     | 2087     |
# |    total_timesteps  | 82721    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0364   |
# |    n_updates        | 21880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 4.93     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 39       |
# |    time_elapsed     | 2114     |
# |    total_timesteps  | 83779    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0337   |
# |    n_updates        | 22144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 4.86     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 39       |
# |    time_elapsed     | 2132     |
# |    total_timesteps  | 84470    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 22317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 39       |
# |    time_elapsed     | 2152     |
# |    total_timesteps  | 85250    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 22512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 4.88     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 39       |
# |    time_elapsed     | 2167     |
# |    total_timesteps  | 85864    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.124    |
# |    n_updates        | 22665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 4.94     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 39       |
# |    time_elapsed     | 2192     |
# |    total_timesteps  | 86825    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00257  |
# |    n_updates        | 22906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 4.83     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 39       |
# |    time_elapsed     | 2209     |
# |    total_timesteps  | 87526    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0814   |
# |    n_updates        | 23081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 4.89     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 39       |
# |    time_elapsed     | 2225     |
# |    total_timesteps  | 88098    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00511  |
# |    n_updates        | 23224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 5.04     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 39       |
# |    time_elapsed     | 2253     |
# |    total_timesteps  | 89176    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 23493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 39       |
# |    time_elapsed     | 2276     |
# |    total_timesteps  | 90099    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0881   |
# |    n_updates        | 23724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 5.23     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 39       |
# |    time_elapsed     | 2292     |
# |    total_timesteps  | 90724    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0586   |
# |    n_updates        | 23880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 5.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 39       |
# |    time_elapsed     | 2312     |
# |    total_timesteps  | 91514    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 24078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 5.28     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 39       |
# |    time_elapsed     | 2331     |
# |    total_timesteps  | 92243    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0648   |
# |    n_updates        | 24260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 5.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 39       |
# |    time_elapsed     | 2351     |
# |    total_timesteps  | 93006    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 24451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 5.16     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 39       |
# |    time_elapsed     | 2368     |
# |    total_timesteps  | 93682    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00419  |
# |    n_updates        | 24620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 5.05     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 39       |
# |    time_elapsed     | 2386     |
# |    total_timesteps  | 94377    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 24794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 4.95     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 39       |
# |    time_elapsed     | 2397     |
# |    total_timesteps  | 94835    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00745  |
# |    n_updates        | 24908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 5.14     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 39       |
# |    time_elapsed     | 2427     |
# |    total_timesteps  | 95984    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 25195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 5.26     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 39       |
# |    time_elapsed     | 2456     |
# |    total_timesteps  | 97072    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 25467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 5.27     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 39       |
# |    time_elapsed     | 2475     |
# |    total_timesteps  | 97838    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 25659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 5.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 39       |
# |    time_elapsed     | 2493     |
# |    total_timesteps  | 98526    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 25831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 5.35     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 39       |
# |    time_elapsed     | 2513     |
# |    total_timesteps  | 99323    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00255  |
# |    n_updates        | 26030    |
# ----------------------------------
# Later training run finished.
# Recording video for spaceinvaders_early...
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:296: UserWarning: WARN: Overwriting existing videos at /content/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Video recording for spaceinvaders_early finished.
# Recording video for spaceinvaders_later...
# Video recording for spaceinvaders_later finished.
# ✅ Videos saved to /videos/

# %%
import gymnasium.wrappers
import gymnasium.wrappers.atari_preprocessing

print("Contents of gymnasium.wrappers:")
print(dir(gymnasium.wrappers))

print("\nContents of gymnasium.wrappers.atari_preprocessing:")
print(dir(gymnasium.wrappers.atari_preprocessing))
# Out:
# Contents of gymnasium.wrappers:
# ['AddRenderObservation', 'AddWhiteNoise', 'AtariPreprocessing', 'Autoreset', 'ClipAction', 'ClipReward', 'DelayObservation', 'DtypeObservation', 'FilterObservation', 'FlattenObservation', 'FrameStackObservation', 'GrayscaleObservation', 'HumanRendering', 'MaxAndSkipObservation', 'NormalizeObservation', 'NormalizeReward', 'ObstructView', 'OrderEnforcing', 'PassiveEnvChecker', 'RecordEpisodeStatistics', 'RecordVideo', 'RenderCollection', 'RescaleAction', 'RescaleObservation', 'ReshapeObservation', 'ResizeObservation', 'StickyAction', 'TimeAwareObservation', 'TimeLimit', 'TransformAction', 'TransformObservation', 'TransformReward', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__getattr__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_renamed_wrapper', '_wrapper_to_class', 'atari_preprocessing', 'common', 'importlib', 'rendering', 'stateful_action', 'stateful_observation', 'stateful_reward', 'transform_action', 'transform_observation', 'transform_reward', 'utils', 'vector']
#
# Contents of gymnasium.wrappers.atari_preprocessing:
# ['Any', 'AtariPreprocessing', 'Box', 'SupportsFloat', 'WrapperActType', 'WrapperObsType', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'annotations', 'gym', 'np']
